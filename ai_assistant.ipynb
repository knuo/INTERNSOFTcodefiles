# %%
import os
import time
import subprocess
import speech_recognition as sr
import pyttsx3
import wikipedia
import wolframalpha
import webbrowser
import datetime
import json
import requests

# %%
print('LOADING YOUR AI PERSONAL ASSISTANT MILO')
# Out:
# LOADING YOUR AI PERSONAL ASSISTANT MILO

# %%
engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
engine.setProperty('voices','voices[3].id')

# %%
def speak(text):
    engine.say(text)
    engine.runAndWait()

# %%
def wishMe():
    hour = datetime.datetime.now().hour
    if hour >= 0 and hour < 12:
        speak("Hello, Good Morning Mr.Karan")
        print("Hello, Good Morning Mr.karan")
    elif hour >=12 and hour <=18:
        speak("Hello, Good Evening Mr.Karan")
        print("Hello, Good Evening Mr.Karan")
    else :
        speak("its already night,  better go to sleep karan")
        print("its alreadt night,  better go to sleep karan")

# %%
def takeCommand():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("I AM LISTENING")
        audio = r.listen(source)

        try:
            statement = r.recognize_google(audio,language='en-in')
            print(f"user said:{statement}\n")
        except Exception as e:
            speak("Parden me, please say that again")
            return "None"
        return statement

# %%
speak('LOADING YOUR AI PERSONAL ASSISTANT.....MILO.....')
wishMe()
# Out:
# Hello, Good Morning Mr.karan

# %%
if __name__=="__main__":
    while True:
        speak("How can i help you ?")
        statement=takeCommand().lower()
        if statement == 0:
            continue
        if "good bye" in statement or "ok bye" in statement  or "stop" in statement :
            speak("Your personal AI assistant MILO is shutting... down.....,Good bye")
            print("Your personal AI assistant MILO is shutting... down.....,Good bye")
            break
        if 'wikipedia' in statement:
            speak("Searching Wikipedia......")
            print("Searching Wikipedia")
            statement= statement.replace("wikipedia","")
            results=wikipedia.summary(statement , sentences  = 3)
            speak("According to wikipedia....")
            print(results)
            speak(results)
        elif 'open youtube' in statement:
            webbrowser.open_new_tab("https://www.youtube.com/")
            speak("Youtube is open for you ")
            time.sleep(5)
        elif "open google" in statement:
            webbrowser.open_new_tab("https://www.goolge.com")
            speak("Google is now open for you")
            time.sleep(5)
        elif "open gmail" in statement:
            webbrowser.open_new_tab("https://accounts.google.com/login")
            speak("Your gmail is open for you")
            time.sleep(5)
       
        elif "weather" in statement :
            api_key = "8ef61edcf1c576d65d836254e11ea420"
            base_url = "http://api.openweathermap.org/data/2.5/weather?"
            speak("What is the city name?")
            city_name=takeCommand()
            complete_url = base_url + "appid=" + api_key + "&q=" + city_name 
            response = requests.get(complete_url) 
            x = response.json() 
            if x["cod"] != "404": 
                y = x["main"] 
                current_temperature = y["temp"] 
                current_humidity = y["humidity"] 
                z = x["weather"]
                weather_description = z[0]["description"]
                speak("the temperature in kelvin units is " + str(current_temperature) + "\n humidity in percentage is "+ str (current_humidity))
                print("the temperature in kelvin units is " + str(current_temperature) + "\n humidity in percentage is "+ str (current_humidity))
            else:
                speak("place not found")
                print("place not found")
        elif "time" in statement :
            strTime = datetime.datetime.now().strftime("%H:%M:%S")
            speak(f"the time is {strTime}")
        elif "who built you" in statement:
            speak("karan built me")
            print("karan built me")
        elif "who are you" in statement:
            speak('I am MILO  your personel assistant. I am programmed to minor tasks like'
            'opening youtube,google chrome,stackoverflow  and gmail , tell  time, search in browser,search  wikipedia ')
            print("")
        elif "open stack overflow" in statement:
            webbrowser.open_new_tab("https://stackoverflow.com")
            time.sleep(5)
        elif "news" in statement :
            webbrowser.open_new_tab("https://timesofindia.indiatimes.com/")
            speak("here are some news")
            time.sleep(7)
        elif "search" in statement :
            statement = statement.replace("search"," ")
            webbrowser.open_new_tab("statement")
            time.sleep(5)
        elif 'ask' in statement:
            speak("I can answer to  computational and geographical questions to try me!! What do you want to ask")
            question = takeCommand()
            app_id = "R2K75H-7ELALHR35X"
            client = wolframalpha.Client('R2K75H-7ELALHR35X')
            res = client.query(question)
            answer = next(res.results).text
            speak(answer)
            print(answer)
        # elif "log off" in statement or "sign out" in statement:
            #speak("Ok , your pc will log off in 30 sec make sure you exit from all applications")
           # subprocess.call(["shutdown", "/l"])
time.sleep(3)
# Out:
# I AM LISTENING
# user said:Dhoni wikipedia
#
# Searching Wikipedia
# Mahendra Singh Dhoni (pronunciation  born 7 July 1981), is a former Indian international cricketer who captained the Indian national team in limited-overs formats from 2007 to 2016 and in Test cricket from 2008 to 2014. Under his captaincy, India won the inaugural 2007 ICC World Twenty20, the 2010 and 2016 Asia Cups, the 2011 ICC Cricket World Cup and the 2013 ICC Champions Trophy. A right-handed middle-order batsman and wicket-keeper, Dhoni is one of the highest run scorers in One Day Internationals (ODIs) with more than 10,000 runs scored and is considered an effective "finisher" in limited-overs formats.
# I AM LISTENING
# user said:open YouTube
#
# I AM LISTENING
# user said:open Google
#
# I AM LISTENING
# I AM LISTENING
# I AM LISTENING
# user said:open stack overflow
#
# I AM LISTENING
# user said:time
#
# I AM LISTENING
# I AM LISTENING
# I AM LISTENING
# user said:weather
#
# I AM LISTENING
# user said:Indian
#
# the temperature in kelvin units is 285.2
#  humidity in percentage is 51
# I AM LISTENING
# user said:weather
#
# I AM LISTENING
# user said:Bangalore
#
# the temperature in kelvin units is 299.77
#  humidity in percentage is 69
# I AM LISTENING
# user said:news
#
# I AM LISTENING
# user said:search
#
# I AM LISTENING
# user said:who are you
#
#
# I AM LISTENING
# user said:who built you
#
# karan built me
# I AM LISTENING
# user said:I know
#
# I AM LISTENING
# I AM LISTENING
# user said:Lockout
#
# I AM LISTENING
# user said:log off
#
# I AM LISTENING
# user said:sign out
#
# I AM LISTENING
# user said:shutdown
#
# I AM LISTENING
# user said:top
#
# I AM LISTENING
# user said:who built you
#
# karan built me
# I AM LISTENING
# user said:where is California
#
# I AM LISTENING
# user said:top
#
# I AM LISTENING
# user said:top
#
# I AM LISTENING
# user said:top
#
# I AM LISTENING
# I AM LISTENING
# I AM LISTENING
# I AM LISTENING
# I AM LISTENING
# I AM LISTENING
# user said:top
#
# I AM LISTENING
# I AM LISTENING
# user said:goodbye
#
# I AM LISTENING
# I AM LISTENING
# user said:ok bye
#
# Your personal AI assistant MILO is shutting... down.....,Good bye
